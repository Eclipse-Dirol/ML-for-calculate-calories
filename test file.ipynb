# %%
import pandas as pd
import numpy as np
import sqlite3
from work_with_db import work_with_db

# %%
full_data = pd.read_csv('data/full_data.csv')

# %%
db = work_with_db()
db.db_entry_from_df(df = full_data)
